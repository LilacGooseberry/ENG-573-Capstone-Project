# %%
import os
import shutil
from tqdm import tqdm
import wave
from IPython import display

# %%
# test_path = 'test_data/'
# valid_path = 'valid_data/'

# if not os.path.exists(test_path):
#     os.makedirs(test_path)

# if not os.path.exists(valid_path):
#     os.makedirs(valid_path)


# data_dir = 'speech_commands_v0.02/'

# with open('speech_commands_v0.02/testing_list.txt') as f:
#     lines = f.readlines()
#     for line in tqdm(lines):
#         # create test/keyword folder
#         source_path = data_dir + line.splitlines()[0]
#         folder = os.path.dirname(line)
#         if not os.path.exists(test_path + folder):
#             os.makedirs(test_path + folder)

#         shutil.move(source_path, test_path + folder)


# with open('speech_commands_v0.02/validation_list.txt') as f:
#     lines = f.readlines()
#     for line in tqdm(lines):
#         # create test/keyword folder
#         source_path = data_dir + line.splitlines()[0]
#         folder = os.path.dirname(line)
#         if not os.path.exists(valid_path + folder):
#             os.makedirs(valid_path + folder)

#         shutil.move(source_path, valid_path + folder)

# %%
number = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
forward_path = 'train_data/forward/'
backward_path = 'train_data/backward/'

forwad_files = os.listdir(path + folder_name[0])
backward_files = os.listdir(path + folder_name[1])

for num in tqdm(number):
    num_files = os.listdir(path + num)
    length = min(len(num_files), len(forwad_files))
    output_path = 'phrase/forward_' + num
    
    if len(forwad_files) <= len(num_files):
        num_files = num_files[:length]
        for i in tqdm(range(length)):
            infiles = [forward_path + forwad_files[i], 'train_data/' + num + '/' + num_files[i]]
            outfile = "forward_" + str(num) + '_' + str(i) + ".wav"
            if not os.path.exists(output_path):
                os.makedirs(output_path)
            data= []
            for infile in infiles:
                w = wave.open(infile, 'rb')
                data.append( [w.getparams(), w.readframes(w.getnframes())] )
                w.close()
            
            output = wave.open(output_path + '/' + outfile, 'wb')
            output.setparams(data[0][0])
            for i in range(len(data)):
                output.writeframes(data[i][1])
            output.close()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:11<00:00,  1.27s/it]

# %%
display.Audio('forward.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display.Audio('four.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
